# %% [markdown]
# # <span style="text-align：center;margin-left:30%"> 情感分类<span>

# %% [markdown]
# <h2>导入分类需要的包</h2>

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
import jieba
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score,confusion_matrix,precision_recall_curve,average_precision_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.externals import joblib
from sklearn.model_selection import GridSearchCV
from pylab import *
from sklearn.model_selection import validation_curve
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
mpl.rcParams['font.sans-serif'] = ['SimHei']
# %matplotlib inline 
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
#处理不需要的词
def data_to_cu(x_sorce):
    contentlist = []
    c = []
    for j in x_sorce:
        text = re.sub("[\s+\.\!\/_,$%^*(+\"\']+|[+——！，。？、~@#￥%……&*（）]+|[\d+]|[a-zA-Z+]|⊙|∀|：", "",j)
        
        current = []  
        for word in jieba.cut(text):
            #if word not in stopword:#去掉停词，然后去掉重复的
            if word not in stopword and  word not in current and word !=' ':#去掉停词，然后去掉重复的
                current.append(word)
        content = ' '.join(current) 
        contentlist.append(content)
    return contentlist

# %%
file = open("停用词.txt",encoding='utf8') 
stopword = [line.lstrip().rstrip() for line in file.readlines()]

# %%
df = pd.read_csv('000001.csv',encoding='gbk')

# %%
df
# Out:
#        阅读量  评价数                           标题 情感  \
# 0     1494    0    股票000816翻倍很容易，000001翻倍很难。  负
# 1     1390    2                   顶背离，赶紧跑，头部  负
# 2     1527    3            海螺水泥和这个那个好？谢谢各位大佬  负
# 3     1334    1                         平安垃圾  负
# 4     1124    0              大盘涨那么多你也没站稳17，哎  负
# ...    ...  ...                          ... ..
# 1792   792    0  14.78元差不多已经到最高价位了，一波比一波拉升距离  正
# 1793  1260    1                    这个架势是要起飞了  正
# 1794   849    1                    别辜负啊，看好你啊  正
# 1795  1045    0                  我艹，竟然板块涨幅第一  正
# 1796  1178    0                     能不能再创新高啊  正
#
#                                                     详情页         作者  \
# 0     http://guba.eastmoney.com/news,000001,89593920...   股友kHe5ti
# 1     http://guba.eastmoney.com/news,000001,89590762...     黄庆帅668
# 2     http://guba.eastmoney.com/news,000001,89586184...       股友哈里
# 3     http://guba.eastmoney.com/news,000001,89579751...        龙尾巴
# 4     http://guba.eastmoney.com/news,000001,89571579...       股票大鼠
# ...                                                 ...        ...
# 1792  http://guba.eastmoney.com/news,000001,87520970...     小明同学9号
# 1793  http://guba.eastmoney.com/news,000001,87520889...  坚持就一定胜利00
# 1794  http://guba.eastmoney.com/news,000001,87520771...   股友iyjuTi
# 1795  http://guba.eastmoney.com/news,000001,87515952...      房and吴
# 1796  http://guba.eastmoney.com/news,000001,87491609...  啦啦啦lalala
#
#                 最后更新   影响力 文章内容  \
# 0     2020/1/3 12:20   3.0  NaN
# 1     2020/1/3 10:55  25.0  NaN
# 2      2020/1/3 9:47   2.0  NaN
# 3     2020/1/2 20:42   2.0  NaN
# 4     2020/1/2 14:21  25.0  NaN
# ...              ...   ...  ...
# 1792  2020/9/6 13:58   4.0  NaN
# 1793  2020/9/6 13:55  15.0  NaN
# 1794  2020/9/6 13:53   2.0  NaN
# 1795  2020/9/6 11:12  15.0  NaN
# 1796  2020/9/5 12:18   2.0  NaN
#
#                                                      评价
# 0                                                   NaN
# 1                          不懂就别说出来给人笑，还顶背离-----傻子。我这里有药
# 2     平安很平安-----都不错，都属于低估-----看主力，都属于周期性股，涨的时候要稳，跌的时...
# 3                                                傻傻分不清楚
# 4                                                   NaN
# ...                                                 ...
# 1792                                                NaN
# 1793                                    你负责坐稳扶好，平银负责嗷嗷飞
# 1794                                              拿住，坐稳
# 1795                                                NaN
# 1796                                                NaN
#
# [1797 rows x 10 columns]

# %%
df.head(5)
# Out:
#     阅读量  评价数                         标题 情感  \
# 0  1494    0  股票000816翻倍很容易，000001翻倍很难。  负
# 1  1390    2                 顶背离，赶紧跑，头部  负
# 2  1527    3          海螺水泥和这个那个好？谢谢各位大佬  负
# 3  1334    1                       平安垃圾  负
# 4  1124    0            大盘涨那么多你也没站稳17，哎  负
#
#                                                  详情页        作者  \
# 0  http://guba.eastmoney.com/news,000001,89593920...  股友kHe5ti
# 1  http://guba.eastmoney.com/news,000001,89590762...    黄庆帅668
# 2  http://guba.eastmoney.com/news,000001,89586184...      股友哈里
# 3  http://guba.eastmoney.com/news,000001,89579751...       龙尾巴
# 4  http://guba.eastmoney.com/news,000001,89571579...      股票大鼠
#
#              最后更新   影响力 文章内容  \
# 0  2020/1/3 12:20   3.0  NaN
# 1  2020/1/3 10:55  25.0  NaN
# 2   2020/1/3 9:47   2.0  NaN
# 3  2020/1/2 20:42   2.0  NaN
# 4  2020/1/2 14:21  25.0  NaN
#
#                                                   评价
# 0                                                NaN
# 1                       不懂就别说出来给人笑，还顶背离-----傻子。我这里有药
# 2  平安很平安-----都不错，都属于低估-----看主力，都属于周期性股，涨的时候要稳，跌的时...
# 3                                             傻傻分不清楚
# 4                                                NaN

# %%
le=LabelEncoder()
le.fit(df['情感'])
# Out:
# LabelEncoder()

# %%
dir(le)
Y =le.transform(df['情感'])
set(Y)
# Out:
# {0, 1}

# %%
y =Y
x_sorce = df['标题'].astype(str).values
contentlist = data_to_cu(x_sorce)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\云海一刀\AppData\Local\Temp\jieba.cache
# Loading model cost 1.425 seconds.
# Prefix dict has been built succesfully.

# %%
contentlist
# Out:
# ['股票 翻倍 很 很难',
#  '顶背离 赶紧 跑 头部',
#  '海螺 水泥 好 谢谢 大佬',
#  '平安 垃圾',
#  '大盘 涨 没 站稳',
#  '傻 逼庄 拉不上',
#  '大盘 大跌 将要 三个 跳空 缺口 第三个 后大',
#  '去年 涨 猛 横盘',
#  '一群 大 手压 单 还 涨个 辟 [ 兴奋 ]',
#  '反正 不买 随便 骗',
#  '真 不争气 招行 害 不 害臊',
#  '平安 兄弟 招行 大哥',
#  '爹',
#  '一地 鸡毛',
#  '垃圾股 老子 前天 买 宁波 银行 两个 选',
#  '玩意儿',
#  '一套 高开低走',
#  '购 鈤',
#  '平安 银行 老态 毕露',
#  '扑街 卖',
#  '发现 亏损 状态 还 十七',
#  '早泄',
#  '拉稀',
#  '月份 商誉 减值 高峰期 投资者 回避 高 个股',
#  '股票 翻倍 很 很难',
#  '大盘 好 不涨',
#  '不要脸 东西',
#  '银行 都',
#  '拖后腿 狗东西',
#  '买 跌 卖 涨 韭菜',
#  '傻掉 大盘 红',
#  '我操 操 妈 割 去 买 水泥',
#  '狗 垃圾 去 常熟 银行',
#  '砸 盘',
#  '块 砸',
#  '平安 银行 样子 一看 出货 韭菜 赶紧 跑',
#  '去死吧 傻鸟 银行',
#  '银行 还 被套 没法 玩',
#  '走 没戏 下午 肯定 被套',
#  '看着 揪心',
#  '拉稀',
#  '看 屁量 出货 初期 阶段',
#  '走势 套 人 节奏 草泥马',
#  '只票 稳定性 好差 小盘 次新股',
#  '平安 银行 砸 盘 工具',
#  '瓜皮',
#  '最辣鸡',
#  '一地 鸡毛 还好 上周五 跑 平安 银行 真的 垃',
#  '丢人',
#  '马上开 砸',
#  '垫底',
#  '平安 一点 都 不',
#  '早上 割 一气之下 均线 吸 中兴 证券 收盘 终于 扬眉',
#  '不 平安',
#  '银行 股 只 持有 一支 不给力 [ 哭 ]',
#  '银行 抛弃 都 去 买 证券',
#  '真 他妈的 浪费 行情',
#  '为啥 银行 股 都 涨 却 砸 盘',
#  '合作 一点',
#  '不让 人 好好 过年 节奏',
#  '小散 应 尽快 离场 钱 交给 机构 买 矛台 军工 宁波 招行 科大',
#  '年 上半年 平安 银行 计提 资产 减值 损失 合计 亿',
#  '四季度 净利润 都 小于 前 季度',
#  '还好 早上 趁势 闪人',
#  '买 没赚 钱',
#  '别装 点 半 大跳水',
#  '沃糙',
#  '量 小心',
#  '估计 向下 走',
#  '大盘 双头 成立 清仓',
#  '外资 没 干活 大 歇菜',
#  '垃圾 内地 鸡狗 玩 尾盘 拉',
#  '尾盘 拉升 次日 略 高开 都 出货 股',
#  '垃圾',
#  '大盘 跌 见',
#  '去 买 铁路',
#  '估计 调整 一个月',
#  '平安 已 不',
#  '为啥 跳水',
#  '这货要 跌',
#  '全逃',
#  '情况 都 助攻 大盘 拉升 掉头 向下',
#  '平安 银行 尾盘 指数 大跳水 危险',
#  '压单 收',
#  '垃圾 够',
#  '赶紧 跑 大跌',
#  '赶紧 卖 听 不会错',
#  '都 不 跑 跌 →',
#  '股市 活雷锋 毫不利己 专门利人',
#  '垃圾 玩意',
#  '快 丢',
#  '短期 缩量 见 顶 跑步 离场',
#  '最 妈 垃圾',
#  '一月 提前 启动 本周 反正 都 只 跌 不涨',
#  '平安 银行 位置 太高 需 回调 三分之一',
#  '垃圾 最',
#  '平银 为啥 还 绿 招行 都 红',
#  '去 尼玛 卖 不 涨',
#  '尾盘 卖出 平安 买进 华谊 兄弟',
#  '尾盘 必拉 减仓 快',
#  '平安 银行 不 涨 庄家 压盘',
#  '最 垃圾 银行 股',
#  '关键 量 人买 先 走',
#  '证 劵 疯 完 银行 疯完 散户 被套',
#  '垃圾 货',
#  '平安 太 垃圾',
#  '好 走下坡路',
#  '尾盘 必拉是 出 掉 机会',
#  '出货 行情',
#  '一分钱 玩 一毛钱',
#  '干 宁波 银行',
#  '剩下 卖 一股 不留',
#  '就别 想 卖 空仓',
#  '不经 夸 泄',
#  '爹 中信 建投',
#  '去 尼玛 卖',
#  '没买 苏州 银行 却 选 名声在外 平安 选错',
#  '南宁 百货 [ 微笑 ]',
#  '跑 一个亿',
#  '买 跌 对不起',
#  '垃圾 错错 错',
#  '招行 突破 历史 新高 平安 银行 怕',
#  '招商银行',
#  '国家队 砸 盘 快 逃命',
#  '这单 抛出',
#  '节前 只退 不 买',
#  '撤',
#  '套人 套 死 这帮 小 韭菜',
#  '辣鸡 能涨 平安 都 倒闭',
#  '',
#  '去 妈 傻 逼 股',
#  '走人 留下 发财',
#  '走 珍惜 好 行情 去 找 活跃股',
#  '卖 去 尼玛 大盘 涨 不涨',
#  '上方 压力 大 砸 盘',
#  '国家队 压 指数',
#  '憨 批 故意 压价 [ 买入 ]',
#  '完蛋 狗东西',
#  '春节 前 不 恋战 节后',
#  '垫底',
#  '跌',
#  '不 机会 是不是 套',
#  '破 卖 留下 三分之一',
#  '平安 这是 偷偷 告诉 快点 闪闪 闪 [ 赚大 ] 亏大',
#  '破 不了 [ 大笑 ]',
#  '扶不起 阿斗',
#  '明天 新低 这货',
#  '明天 低开',
#  '牛 逼 都 平安 不',
#  '真 他妹 无语',
#  '好 平安 带头 砸 盘',
#  '看空 融券 发财 哈哈哈哈',
#  '好 千万别 参与 跌',
#  '护盘 资金 买 指望 拉升',
#  '一卖 涨',
#  '跑 路 祝 留下 兄弟 发财',
#  '一卖 涨',
#  '半年 持仓 中 第一个 割肉 股祝 留下 发财',
#  '跑 股市 本来 赚钱 套日 狗',
#  '常熟 银行',
#  '卖 涨 尼玛 做',
#  '好 全 下车',
#  '平安 不安',
#  '真他妈 垃圾 买个 银行 天天 绿',
#  '卖 跌',
#  '天天 除了 绿',
#  '',
#  '最不愿 银行 板块 指数 下跌 创业板 上涨',
#  '套 尼玛',
#  '抛出 人 洋洋得意 持股 垂头丧气 [ 大笑 ]',
#  '算你狠',
#  '明天 低开 低 走',
#  '反弹 跌跌 不休',
#  '垃圾 非常',
#  '[ 滴汗 ] 没想到 弱',
#  '明天 妈 肯定 绿',
#  '奇臭 无比',
#  '醒醒',
#  '回到 保证 不玩 [ 傲 ]',
#  '银行 股一 坨 屎 拉 不',
#  '跌到',
#  '孙子',
#  '低吸 机会',
#  '垃圾 玩意',
#  '暴跌 两次 再 买',
#  '辣鸡行 [ 亏大 ]',
#  '还金 叉叉 不死',
#  '下跌 才 刚刚开始 目标价 九元',
#  '年分 买入 好 平安 银行 请 吃',
#  '涨 角钱 再也 不玩 股票',
#  '看样子 还要 下跌 [ 滴汗 ]',
#  '天天 诱多 一浪盖 一浪 恶毒 至极',
#  '对不起 拖 后腿 不该 买进 垃圾',
#  '废 装死 [ 抄底 ]',
#  '拉圾 没救',
#  '融券 做空 才能 赚 都 浮云',
#  '没 人 骂',
#  '这弱 鸡 动不动 跌 包尾 太 不 镇定',
#  '垃圾 还要 跌',
#  '股票 波动性 判断 风险 很傻 两',
#  '月 号 万股 平安 银行 价位 盈利 个点 全',
#  '骗 二年',
#  '资金紧张 年底 回笼 结算 大盘 跌',
#  '坑',
#  '垃圾 平安',
#  '补 银行 坏帐 该死 平安',
#  '废',
#  '底裤 攻破 事业有成',
#  '娘 亏 八个 点',
#  '大盘 收红此 股 却 阴包 阳将 昨天 上涨 全 吞掉 后市 回',
#  '周 级别 月 调整',
#  '没什么 利空 月 获利 筹码 走',
#  '擦 妈 清仓 垃圾',
#  '这货 近期 趴窩 走势',
#  '辣鸡行 倒数 第三 [ 滴汗 ]',
#  '想 骂人',
#  '中国 平安 没涨 涨 不了 太',
#  '都 跌元 位置 一个多月',
#  '平银 阴跌 血洗 散户',
#  '天道 轮回 当跌 不 跌 后边 必有 大跌',
#  '大盘 未动 先行 平安 跌停',
#  '特么块 本怕 回不来',
#  '平安 银行 完蛋 数字 货币 第一 深圳 试点 没用',
#  '平安 银行 轴 下方 弱市 增持 滞涨 向上 民生',
#  '啥时候 个头',
#  '高兴 下周 阴跌 不',
#  '平安 银行 外资 高位 减持 对象 危险 超大 帐户 净流',
#  '兴业银行 平安 银行 都 外资 高位 减持 对象 危险',
#  '劳资 割 本事 跌 辣鸡',
#  '尼玛 最高点 一份 [ 哭 ]',
#  '平安 银行 外资 抛售 无量 反 抽 诱多 季节',
#  '平安 银行 想当 救世主 砸 观看 跳水 表演',
#  '顶背离 弱市 反 抽 诱多 快乐 观看 尾盘 跳水 象',
#  '成功 洗掉 还 没亏',
#  '不高 前 两次 割肉 赚 回来 就行 估计 还 割 第三',
#  '无量 反 抽 诱多后 跳水 快乐 观看 鸡肋',
#  '还 亏 月底 回本 [ 想 ]',
#  '亏了 几十元 好 怕 [ 大笑 ]',
#  '你妹 三次 被套',
#  '再也 不 碰 机构 股坑 太多',
#  '去 麻痹 垃圾股 滚 出 自选',
#  '随便',
#  '追高毁 一生',
#  '跑 完 低吸',
#  '下午 指定 跌',
#  '还 没 调整 到位',
#  '这烂 银行',
#  '跌',
#  '日 尼玛 割 辣鸡',
#  '表现 太 差劲',
#  '多辣鸡',
#  '涨 不了 还 没 跌 到底',
#  '烂',
#  '真 操蛋 会 绿',
#  '',
#  '亏卖 [ 傲 ]',
#  '不知 套 多久 走法',
#  '说 垃圾股',
#  '出息 股票',
#  '尾盘 诱多 反 抽 周四 下跌 重挫 淡定 观看 跳水',
#  '明天',
#  '一点 都 不 平安 下方 赚 至少 割 下',
#  '被套 五个 点',
#  '年线 靠拢 跌至块 企稳 此股 必破净',
#  '真 垃圾 跌',
#  '倒 开 新仓 调 利润 明年',
#  '大盘 不涨 弱鸡',
#  '鸡狗 天天 左手 倒 右手 不用 交 印花税',
#  '涨 天天 回去',
#  '银行 闭',
#  '狗屎 垃圾 中 涨 一分 都 难 跌 几毛',
#  '可恶',
#  '清仓',
#  '主力 天天 出货',
#  '怎么回事',
#  '天气晴朗 万里无云 却 阴跌',
#  '平安 不',
#  '不要脸 玩意',
#  '补 银行 坏帐',
#  '接',
#  '平安 银行 盲目崇拜',
#  '只 关注 不 增持',
#  '赶快 跌下去 [ 怒 ]',
#  '一点 出息 都',
#  '港股 跌 近点 近期 大 不 乐观',
#  '不 补缺 口 不进',
#  '割要 一次性 割完 割 最 伤心',
#  '服 买 股 都 垃圾',
#  '螬 垃圾 [ 哭 ]',
#  '不 割肉 疼 都 还 装 死',
#  '领跌 不 领涨',
#  '大 银行 跌成 狗 服',
#  '昨天 清 四分之三 妈呀 今早 看好 大 一个 绿洞',
#  '大宗 交易 都 块 贱卖',
#  '妈 垃圾',
#  '空仓 选择',
#  '平安 银行 托单 诱多 快乐 下跌',
#  '尾盘 跑 不少 主力',
#  '都 跑 庄家 接盘 [ 大笑 ]',
#  '愉快 吃 雪糕 元 清仓 正确 明天 早上 低开 低',
#  '兴业银行 跑',
#  '妥妥 雷 特大 主力 慢悠悠 出货',
#  '鸡狗 还 诱多 出货 中',
#  '已 卖出 跑 路 还要 跌 想引 上钩',
#  '上方 全是 字 尾巴 元手 清仓 慢慢 玩',
#  '平安 银行 上方 全是 大单 非常 讨厌 鄙视',
#  '都 换 招行 反弹 快 主力 砸 帮 时 无力 回升 割主',
#  '跟着 鬼佬 买 被套',
#  '他妈的 被套 个点',
#  '真 后悔 上周五 没买 小招 买 垃圾 [ 好 困惑 ]',
#  '这票',
#  '拉 麻痹 赶紧 跌下去',
#  '股不涨 平安 银行 中国 涨 不了 占 权重 太 大',
#  '清仓 走人 拜拜 再也 不见',
#  '平安 系妥 妥 雷',
#  '大宗 交易 都 还 幻想 涨 真要 好好 休息',
#  '表现 好 依旧 低位 低估 品种',
#  '平安 银行 上方 多大单 小明 好 害怕',
#  '猫咪 平安 银行 上方 好多 抛单',
#  '弱',
#  '年末 都 会 跌中 金黄 金银 泰 黄金 买',
#  '这票 入手 人 心寒 成鸡 鸡肋',
#  '垃圾 厉害 流入 多万 流出',
#  '破 装死',
#  '再 瘟 讲 一遍 春节 前元见',
#  '搞个 蛋 早上 万股 全出 不 关注',
#  '收盘 怒涨 一分钱 行 不 [ 傲 ]',
#  '股市 永远 别碰 太坑',
#  '哥姐 弟妹们 是不是 月线 级别 调整',
#  '一个 馅饼',
#  '进来 [ 鼓掌 ]',
#  '诱多 跌',
#  '不争气 东西',
#  '平安 银行 诱多后 跳水 回调 结束 券商 诱多',
#  '涨 跌 三天 真 垃圾 利空',
#  '绿',
#  '进 垃圾股',
#  '真不该 垃圾 存有 幻想',
#  '垃圾 [ 微笑 ]',
#  '机构 都 减仓 自由落体',
#  '大 白马 大绿马 ； 年底 机构 换色',
#  '垃圾 平安 银行 连续 五周收 阴线',
#  '令人 心痛 跌得 狠',
#  '尾盘 拉升 周一 还要 跌',
#  '割 过年 [ 成交 ] 滴汗',
#  '跌 一点 慢慢 割才 痛',
#  '暴跌 怕 阴跌',
#  '跌 三毛 再 十天',
#  '开个 方子 跌二毛 十三元 二周 慢慢',
#  '底 平安 银行 垃圾',
#  '幸亏 跑',
#  '无 底线 跌',
#  '我错 亏 哭 [ 好 困惑 ]',
#  '午底 该补 死 帐',
#  '狗屎 垃圾 都 不 骂',
#  '这一波 确实 反弹 一路顺风',
#  '底线',
#  '下 看 啥时候 到底',
#  '买 跌',
#  '借点 钱来 加仓 [ 哭 ]',
#  '快抢 月线 历史 大底',
#  '买 洋河 跌买 平安 银行 跌 中国 人保 [ 哭 ]',
#  '亏前 几天 卖 平安保险 跌成',
#  '银行 证券 不 护盘 还跟着 砸 月 亏 惨',
#  '扶不起 阿斗',
#  '破 凉凉',
#  '跌 看 权重 完 才 行情',
#  '最低 更 低',
#  '求 告知 个头',
#  '出掉 再 慢慢 吃',
#  '年 后 元 见 慢慢 熬 都 减仓 清仓',
#  '跌 一点',
#  '分钟 周期 天花板 行情 股价 下 杀',
#  '周线 月 线 挂 历来 走势 跌个',
#  '跌法 [ 兴奋 ]',
#  '跌法 [ 兴奋 ]',
#  '元 后会 破 站岗 惨',
#  '银行 上涨 平安 下跌 还 回',
#  '麻辣 隔壁 天天 跌',
#  '缺口 补',
#  '卧槽 情况',
#  '完 歇 逼',
#  '废柴',
#  '真 垃圾 真他妈 无 语',
#  '股价 下跌 至元 附近 缩量 反而 增加',
#  '这波套 多人',
#  '大盘 凉凉',
#  '下午 再 跌 一毛钱 差不多 [ 鼓掌 ]',
#  '垃圾 中 战斗机',
#  '没 上涨 反弹 都',
#  '被套 住 [ 哭 ]',
#  '非 逼 做 股东',
#  '平安 银行 憨 废物 一个',
#  '银行 板块 跌 最',
#  '平安 银行 领导 是不是 该换 股价 别人 随意 蹂躏',
#  '大盘 好点 银行 就要 砸 盘 狗日 控股 人',
#  '都 涨',
#  '这次 真的 好弱',
#  '平安 人 死 想',
#  '会 跌 跌点 加带 力度 嗷',
#  '中国 股市 真 马 垃圾',
#  '平安 砸 块 [ 大笑 ]',
#  '这货要 跌 元',
#  '狗屎 垃圾 中',
#  '下 砸',
#  '这货 新低 [ 滴汗 ]',
#  '阴跌 不止',
#  '买 垃圾股 倒霉 套住 走 不了',
#  '尾盘 拉一波',
#  '垃圾',
#  '空仓 不 害怕 加油 跌',
#  '分 玩 [ 想 ]',
#  '真 垃圾桶 人 玩',
#  '全卖',
#  '儿子 中国 平安 还 跌 喔',
#  '股票 砸 大盘',
#  '往下 砸',
#  '一分钱 玩',
#  '无语',
#  '跌 鸭 加仓',
#  '会破净',
#  '垃圾 一个月 天天 绿帽',
#  '平安 平时 量 都 [ 困顿 ]',
#  '辅助 招商 大哥 拉 大盘 明天 深绿 不 低于',
#  '买 上 跌',
#  '快乐 黑 周四 平安 银行 回调 结束 跳水',
#  '腰斩 打个 折 主力 做空 赚',
#  '表演 [ 哭 ]',
#  '完 喽',
#  '平安 银行 板块 慈善家 涨时 激流勇退',
#  '高点 巳 经跌 去 重仓 主力 砸',
#  '高点 跌去',
#  '请问 天天 跌',
#  '明天 亿 保不住',
#  '买入 套 不知 倒霉',
#  '年前 银行 都 跌 去年',
#  '心存侥幸 中期 趋势 已成 加速 下跌',
#  '无比 失望 招行',
#  '底 何方',
#  '不破 提头 见',
#  '有雷 平安 系',
#  '平安 银行 多方 非常 被动',
#  '去',
#  '平平安安 拉稀',
#  '不撑 指数 天天 拉稀',
#  '阿里 上市 扩容 利好 股 没',
#  '头 天天 跌 跌停板',
#  '垃圾 去',
#  '买 垃圾 天天 想 骂人',
#  '',
#  '事儿 怨 转换 三支 股票 每支 都 一买',
#  '最低 更 低',
#  '钓鱼 线 吸引 不少 接盘 侠 诱多 改变 不了',
#  '真',
#  '平安 银行 不',
#  '卖 草 太 垃圾',
#  '简直 一坨 屎 [ 围观 ]',
#  '学学 招商',
#  '建行 平安 国务院 点名 批评 小微 贷款 捆绑 销售 背',
#  '下午 拉高 诱多 勿 追',
#  '诱多后 跳水 下午 俯冲 式 轰炸',
#  '稳 指数 靠 招行 平安 龙头 已 废死',
#  '垃圾 主力 特么 都 跌 近期 低点 套进',
#  '完 真 后悔 买 货下 年 解 不了 套',
#  '平银 垃圾 主力 真的 很 恶心 活埋 人 可惜',
#  '明年 还会 回到 元',
#  '终于 跌破 亿',
#  '阴跌 不 一次性 大跌 希望',
#  '砸 盘 好像',
#  '都 买单 难道 越买 越 跌',
#  '一分钱 荡秋千',
#  '真 没人敢 买 跑 跑不了 太过 拉圾',
#  '成本 割肉',
#  '好 垃圾 割 算了',
#  '见 鬼 买进 股 都 垃圾',
#  '龟孙 都 没 正经 涨过',
#  '考 天天 跌',
#  '低 回升',
#  '天天 跌 情况',
#  '带头 大哥 成',
#  '一段时间 再 犹豫 割 走 好',
#  '还要 跑 垃圾 中 [ 微笑 ]',
#  '够',
#  '狗屎 垃圾',
#  '平安 废',
#  '一首 凉凉 送给 [ 哭 ]',
#  '平安 下 注意安全',
#  '垃圾 中 有害',
#  '万手 拉升 分钱 主力 沙雕',
#  '垃圾',
#  '至少 见到',
#  '垃圾',
#  '有毒 垃圾',
#  '新低',
#  '垃圾',
#  '外资 没看 上 这货',
#  '平安 银行 不 吃 泻药',
#  '清仓 休息 铛铛 铛',
#  '平安 真的 走 拉 胯 模式 开启',
#  '宁银 砸 平银 龙头',
#  '天天 割 韭菜',
#  '昨天 割 买 不知 不',
#  '败家子 别人 送 钱',
#  '挣得 钱 还 股票 跌 辣鸡',
#  '明晟 扩容 总得 砸 底 一群 败家子',
#  '大盘 走成 鸟样',
#  '亿 票 跌成 鬼 样子 股票 不亡 才 怪',
#  '接下来 破 反正 有托单 必破',
#  '明天 跌',
#  '亏死 撤退',
#  '跌破 债转股 元价 再 买',
#  '托单 必破',
#  '挣扎',
#  '下跌 趋势 已成 大跌',
#  '还 想 涨涨 妈 鬼 去 下方 托 单一 大堆 [ 微笑 ]',
#  '还 高 都 没 跌',
#  '守 不住 出货',
#  '一路 溃败 毫无 还手 之意',
#  '好 垃圾',
#  '狗庄 故意 打压',
#  '跌 鸭',
#  '早上 卖 买 回来',
#  '专套 北上 资金',
#  '拜拜 垃圾 盘子 大 还 跌 傻 逼 股',
#  '天天 跌',
#  '割肉 再 不 碰 股票 删',
#  '够 庄 有没有 过元 股民 拉稀 跌个 不停',
#  '早 走 还 劝 老铁早 跑 不 看涨',
#  '平安 银行 欲罢不能 不知 收场',
#  '进来 死路一条',
#  '股市 平安 烂票 一枚 割肉',
#  '清仓 不 碰辣鸡',
#  '真 没救',
#  '两阴 夹 一阳 空方 炮 速撤',
#  '买 中国 平安 银行 都 错误 坑 惨',
#  '太扯',
#  '半小时 昨天 升幅 搞掉',
#  '银行 垃圾',
#  '平安 银行 表现 确实 太 垃圾',
#  '垃圾 配高开',
#  '平安 银行 回 不了 割肉 [ 哭 ]',
#  '月线 级别 调整 老乡 躲躲',
#  '股民 钱 去 补 坏帐',
#  '清仓',
#  '清仓 大 甩卖 大单 托盘 卖',
#  '狗 鸡巴 买 好过 天天 拉稀 不止',
#  '网贷 关闭 家 银行 挂',
#  '垃圾 早盘 追 高清',
#  '估值 太高 还 跌',
#  '跌 拉高 出货',
#  '赵 老哥 出货',
#  '不行 滚下来',
#  '认栽 走 人',
#  '历史 证明 国家队 作对 好 果子吃',
#  '银行 带头 大哥 成 拖后腿',
#  '他妈的 最 弱',
#  '上方 压力 山 大',
#  '散户 拼 老命 跑 主力部队 赶紧 加仓',
#  '回来 一买 跌',
#  '跑 喽',
#  '垃圾',
#  '卧槽 没看 错 基金 还 没出 完货',
#  '惨',
#  '跌',
#  '极弱 抛弃',
#  '明天 跌别 安慰 分析 都 跌',
#  '震荡 下行 回避',
#  '明天 还 跌',
#  '有票 赶快 走 此后 长期 下跌 周期',
#  '破位 还 讨论 抄底 死 扛 干脆 离开 市场 良心话',
#  '水平 一周 亏了 一个月 利润',
#  '下周 还 跌 估计 洋河 节奏 差不多',
#  '本来 想 抄底 没想到 底 抄 [ 哭 ] 站 高岗',
#  '这周 跌 最 厉害 下周 还',
#  '破股 向下 倒',
#  '大盘 涨 不涨 跌 倒 厉害 垃圾',
#  '破位 平银 走向 腰斩 路 祝你们 好运',
#  '到底 砸 盘',
#  '天天 跌 尼玛',
#  '蓝筹 白马股 大跳水 年底 鸡狗 资金 获利 抽离 可怜',
#  '平安 银行 来害 股民',
#  '几天 都 最低',
#  '隐约 下周一 大盘 浓浓 绿意 月 不 搞 股票',
#  '啥事 候会 解套',
#  '跑 猪头 玩吧',
#  '周 股市 还 不让 人活',
#  '天天 创新 高 十年如一日 真 没用',
#  '补缺 口去',
#  '银行 不 止跌 永无 低点',
#  '昨天 走 看样子 破元',
#  '跌停 傻 逼',
#  '完 底线 砸',
#  '有毒 跌 去',
#  '此股 深不见底',
#  '小散 爆亏 一个点 解套',
#  '王八蛋 倒数',
#  '股市 祸害',
#  '银行 低估 高位',
#  '跑 全买 黄金',
#  '下跌 中继 别接 飞刀',
#  '下落 刀子 接',
#  '惯性 下跌 买进 好时机 星期一 吃 嘎嘎',
#  '百姓 苦 平安 久',
#  '垃圾 中',
#  '越跌 越 棒棒 哒',
#  '日 狗 股票 涨 跌 烂货 天天',
#  '停牌 开会',
#  '补缺 口',
#  '疯狂 倒 中',
#  '底',
#  '北向 资金 整仓 被套 百分之十',
#  '看 成交量 多头 大军 还 观望 [ 围观 ] 再 一个 小时',
#  '不动 卡住 没 网络',
#  '没人接 盘 垃圾 玩 都 人',
#  '还 卖 价格 刚跌 点 跌 天线 考',
#  '大宗 交易 诱空',
#  '妈',
#  '鼻 疯 天天 跌',
#  '天天 闹 哈哈哈',
#  '跌停',
#  '平安 垫底 牛 逼',
#  '真的 挺无语',
#  '起不来',
#  '垃圾股 [ 大笑 ]',
#  '买 完 垃圾',
#  '跌 可真 他妈的 六亲不认',
#  '尼玛 亏了 十几个 点 回 不了 [ 哭 ]',
#  '稳坐 倒数 第一 [ 胜利 ] 学费 多谢 指教',
#  '崩',
#  '倒数 草 尼玛',
#  '爬下来 起不来 真弱',
#  '保不住',
#  '年前 处于 下跌 趋势 不买',
#  '好 久美 见 涨 是不是 表现',
#  '我割 涨 [ 滴汗 ]',
#  '落后 大盘 行业 大 平安 到底 煮',
#  '都 宇宙 行排 倒数 第一第二 争位 赛',
#  '调整 离场',
#  '最惨 高位 接 银行 傻',
#  '快 跑 两个 星期 就要 大跌',
#  '新低',
#  '平安 真 厉害 亏了 五千',
#  '短期 回调 改变',
#  '爸爸 跌成 屎 倒',
#  '跑',
#  '卖',
#  '购币 平安 太 垃圾 跳空 低开 低 走走 都 走 不了',
#  '卖',
#  '购币 平安 爱 垃圾',
#  '大 概率 补缺 口',
#  '马上 下跌',
#  '平安 银行 救',
#  '平安 银行 不',
#  '大 资金 撤',
#  '先割 香港 外围 股市 大跌 美股 处在 高位',
#  '再 低点 挂 没 买 上',
#  '割',
#  '再 低点',
#  '幸好 没买 平安 银行 不 死翘翘 买 袖珍',
#  '问题 领跌',
#  '刚刚 抛股',
#  '开启 无限 下跌 模式',
#  '垃圾 货 怎么回事 连续 大跌',
#  '雷 弱 [ 亏大 ]',
#  '瘪 犊子 敢不敢 跌 昨天下午 抄到',
#  '垃圾 始终',
#  '不用 看 起码 调 明年 月份',
#  '砸 盘 大举 出货',
#  '外围 都 大跌 跟上 会 很 尴尬',
#  '日',
#  '真的 垃圾',
#  '我出',
#  '命',
#  '平安 建行 爆炸',
#  '换 王府井 机会',
#  '真的 不 平安',
#  '跌 主力 互砍 更惨',
#  '还 跌',
#  '跌',
#  '卖',
#  '再 暴跌 个点 捡 点 便宜 筹码',
#  '空 打败 清仓',
#  '大跌 希望 会 蓄力 反弹 走势',
#  '银行 龙头 放量 破位 大盘 还 底',
#  '平安 银行 - 周三 今日 放量 大跌',
#  '平安 银行 被套 个点 不 才能 解套',
#  '银行 股 都 垃圾',
#  '平安 系 印象 不太好 总有 怪怪的 感觉 招商 还',
#  '只许 干坏事 还 不准 骂 下 亏了 出 讲 不讲理',
#  '',
#  '跌 机构 疯狂 跑 路 晚上 会 发布 利空',
#  '真 牛 逼 大盘 硬生生 扯下来 [ 怒 ]',
#  '看 一眼 还 退市 股 [ 傲 ]',
#  '年底 漫长 阴跌',
#  '银行 股跌 真够 狠',
#  '老虾 扯蛋 被套 三成 仓',
#  '单日 跌幅 明天 大 概率 反包',
#  '烂股 腰 宰 都 分 人为 操控 包括 波行',
#  '超卖区',
#  '放量 下跌 还要 跌',
#  '分时图 次 反弹 摸 均价 线 明天 低点',
#  '跌 半年线 太 无情',
#  '厉害 眼睁睁 看着 万手 托单 撤 降到',
#  '收盘',
#  '有何 利空 跌得 惨',
#  '成功 拉 下 银行 板块',
#  '来害 股民',
#  '终于 前仆后继',
#  '散户 傻掉 快 接盘 [ 大笑 ]',
#  '见 顶 银行 股 大跌',
#  '跌 多点 散户 惨 机构',
#  '机构 都 逃散 户 接 傻子',
#  '平安 银行 漫长 熊市 展开 股民 机构 逃命 机会 赶快 落',
#  '这才 放量 下跌',
#  '明天 还会 跌 再 买 [ 想 ]',
#  '收盘 估计 跑 亿',
#  '暴雷 股东',
#  '明天 低开',
#  '平安 银行 出事',
#  '砸 不 确实 情况',
#  '尼玛 买 再也 回不去 [ 哭 ]',
#  '垃圾 狗屎',
#  '情况 跌成',
#  '啥时候 成辣鸡 股',
#  '进场 早',
#  '倒闭 节奏',
#  '鼻 还好 早上 卖 换 软件 全是 补 回来',
#  ') 利空 跌 折磨',
#  '完 平安 银行',
#  '跌幅 够 大 都 破 底价',
#  '实在 对不住 早盘 全出',
#  '为啥 砸',
#  '厉害 成功 拉 下 银行 板块',
#  '前期 赚 都 交待 从头越',
#  '不行 横盘 阿弥陀佛',
#  '托单 必破',
#  '完美 破位 先 走 玩',
#  '平安 系 大盘 趴在 地上',
#  '好惨',
#  '这波 狠',
#  '大哥',
#  '破位 跌途 刚 出发',
#  '向下 破位 行长 事件 威力 太大',
#  '完美 被套 牛 逼 傻子 玩 [ 微笑 ]',
#  '愿赌服输 挨打 立正 下车',
#  '银行 股雷 大都 种',
#  '妈呀 砸 三个 点 [ 大笑 ] 下输',
#  '看不懂 跌',
#  '昨天 刚买 跌成 服',
#  '不错 天天 墨迹 洗',
#  '银行 跌 真心 看不懂 指点',
#  '美股 一跌 扒 下装 屎',
#  '有没有 大能 分析 下跌',
#  '跌破 日 均线 干嘛',
#  '劝 银行 股 碰 散户 钱 都 黑洞',
#  '早上 平安 证券 出 故障 交易 损失惨重',
#  '双头 速速 卖出',
#  '霉 逼',
#  '这跌 厉害',
#  '去掉 散户',
#  '放量 下跌 量 比高 再 不 跑 留下 做 股东',
#  '奶奶 银行 都 拉',
#  '割肉 五百多 走 [ 哭 ]',
#  '鸟 玩意',
#  '这银 胆大 不 规范 见 人 发卡',
#  '银行 块板 带下',
#  '国务院 通报 平安 建行 借贷 搭售 转嫁 成本 问题',
#  '清仓 再也 不想 买',
#  '破位 出局 观望 没 毛病',
#  '断崖 式 暴跌 [ 滴汗 ]',
#  '成交 巨量 垃圾',
#  '怕 撤',
#  '早该 砸',
#  '玩不动',
#  '作死 咯 跌成',
#  '厉害 使劲 砸 银行 垃圾',
#  '估计 暴雷',
#  '尼玛 休想 洗出去 能耐 跌倒 块 草泥马',
#  '错 买入 跌 成翔',
#  '卧槽 无情 暴雷',
#  '这是 股票 不行 还要 跌 不少',
#  '错 买入 跌',
#  '辣鸡股',
#  '大癌 股带 崩',
#  '完 犊子',
#  '蓝筹股 大 白马 变 大白熊',
#  '垃圾 无语',
#  '终于 很 久',
#  '沃日 爹 德行',
#  '难道 散户 砸死',
#  '再 不 跑 来不及',
#  '永远 最 熊 逼',
#  '普涨 跌 大盘 涨',
#  '建设银行 平安 银行 国办 督查 室 银保监 通报批评 抬高 小',
#  '服 操盘手 估计 一帮 阳痿 货',
#  '老子 买 自选 里 唯一 一个 绿票 醉',
#  '删 自选',
#  '炒 区块 链 不 银行 涨 大盘',
#  '罚款 没 钱 拉',
#  '购 鈤',
#  '银行 股 好日子 到头 科技股 发力 撤 拜拜 孙子',
#  '北向 出货 保重 [ 摊手 ]',
#  '典型 涨 不 跌 废物',
#  '盘久 必跌',
#  '罚款',
#  '人渣 股',
#  '真 尼玛 辣鸡',
#  '废',
#  '贱',
#  '垃圾 劳资 撤 不 玩 滚 犊子',
#  '上 不 去 下',
#  '上 深指 排行榜 跌幅',
#  '垃圾 横着 横 跌',
#  '一分',
#  '压着 不涨 王八',
#  '一分钱 玩',
#  '这票 割洋 韭菜 莫 介入',
#  '真的 无限 徘徊',
#  '唯一 重仓股 绿色',
#  '出 垃圾',
#  '尼玛 稳 跌 完',
#  '麻个 閪 资金 流出 能力 牛得 逼',
#  '废物 一个',
#  '早绿晚 红',
#  '大盘 飞 都 绿',
#  '服气 不服 不行',
#  '跳水 模式',
#  '跌 痛快 点',
#  '特立独行',
#  '垃圾 中 有害',
#  '垃圾 跑',
#  '压力 位 横盘 好 几天',
#  '自选股 都 红 绿色',
#  '阳痿 男',
#  '都 狗屎',
#  '罚 五十万 大 利空',
#  '国务院 出手 点名 批评 建行 平安 北京分行 还 约 谈 总行',
#  '平安 银行 发 利空',
#  '违规 贷款 建设 平安 银行 两家 分行 罚 共计 万',
#  '美股 今晚 暴跌',
#  '平安 永亿 学习 天天',
#  '平安 银行 真的 废 没 办法 玩',
#  '还 宁波 银行 先 而行 很 久',
#  '垃圾',
#  '尼玛 气人 不',
#  '废材',
#  '太扯',
#  '老套路',
#  '银行 放贷 强制 搭售 保险 国务院 通报 平安 建行 违法',
#  '牛 逼 开盘 啥样 收盘',
#  '收盘 回 原点',
#  '清仓 走 人',
#  '贱 板块 都 涨',
#  '完美 诠释 儿子 爸爸',
#  '今晚 美股 暴跌',
#  '垃圾 清仓',
#  '今晚 美股 暴跌',
#  '骗人',
#  '今晚 美股 暴跌',
#  '落后 板块 涨幅',
#  '要死不活 一天天',
#  '麻痹 好 废',
#  '不上不下 真的 烦',
#  '宁波 银行',
#  '买到 最 垃圾 票',
#  '低开',
#  '买 一百 股 被套 不开森',
#  '跌 无可 都 不想 位置 丢 筹码',
#  '下午 回调 这是 跑 机会',
#  '每次 追高 都 韮 菜 远离 股市',
#  '卖',
#  '天天 跌',
#  '买 蓝筹股 想 暴涨 去 别家',
#  '这股 快 外资 玩坏 几亿 做 涨 不',
#  '平安 感觉 近期 瓶颈 反弹 无力 大盘 走势',
#  '恶心 他妈 烧纸 死',
#  '狗日 回来',
#  '狗日 平安',
#  '两分 钱 玩 [ 滴汗 ]',
#  '令人恶心',
#  '麻个 逼',
#  '绿',
#  '垃圾 清仓',
#  '使劲 跌',
#  '专为 砸 尾盘 规律',
#  '都 跑',
#  '买 埋',
#  '真 拉 有人 今晚 美帝 崩盘 活埋 进去',
#  '瞎了眼 买 狗屎',
#  '老是 要死不活',
#  '傻子 都 破 平台',
#  '垃圾 帅 三秒',
#  '昨天 走势',
#  '搞来搞去 不去 宁波',
#  '垂死挣扎 朋友 里面 高管 快 跑 说',
#  '垃圾 别买',
#  '套 人 上车',
#  '想 走',
#  '清仓 走 人 垃圾股 第二个 王 校长',
#  '银行 抽签 高开 护盘 会 低 走',
#  '顶不住 不 持续 高 增长 股价 透支 未来',
#  '坑爹 很',
#  '操 妈 银行 股是 鬼',
#  '钓鱼',
#  '跌得 快涨 不',
#  '鬼',
#  '跌 透透 好',
#  '没买 看着 不错 买进 变 垃圾',
#  '真 尼玛 建压 单对 倒',
#  '指数 还 挺 漂亮 个股 都 跌成 屎 买 股票 日 送',
#  '大盘 不拉 银行 权重 屎 都 不行 股',
#  '刚加 仓 跌 确实 平安 风险 很 低',
#  '超级 大 垃圾 自选股 里 多多 都 资金 流出 最',
#  '日 狗 涨 一点点 拉稀',
#  '炒股 浪费 生命',
#  '天天 倒数',
#  '麻 巴子 骂 都 不为过',
#  '垃圾 中',
#  '傻子 进来 接盘 [ 鼓掌 ]',
#  '持有 股 都 赚钱 亏要 说 你好',
#  '一天天 要死不活 垃圾 平安',
#  '还要 回调 年 主力 成本 块 [ 大笑 ]',
#  '还要 回调 一周 主力',
#  '还要 回调 一周 主力',
#  '妈蛋',
#  '企业 立足 自立 不 寄生 股民 身上',
#  '一步 跌 到位 涨 真烦',
#  '平安 绿',
#  '个股 跌成 狗 托 点 意义 何在',
#  '傻子 快进来 接盘',
#  '死人股',
#  '大胆 买入 腰斩 卖出',
#  '傻子 才 进去 接盘 高位',
#  '糙米 板块 都 涨 特 跌 完',
#  '板块 涨幅 都 跟不上 垃圾',
#  '天天 跌 最 垃圾',
#  '服 逃命 节奏',
#  '轶法 垃圾 到极点',
#  '感觉 还 没 跌 透 拉高 不 踏实',
#  '板块 倒数 嘈腻',
#  '平安 垃圾',
#  '上车 不 发表意见',
#  '回调 不改 趋势',
#  '跌 够 狠',
#  '有人 回事 千股 跌停',
#  '价位 建仓 [ 大笑 ] 长线 短线 都',
#  '大盘 行情 不好 券商 银行 尾盘 大跳水',
#  '鼻 底线 跌 天天 还 每次 倒数 草 尼玛',
#  '股市 算是 没救 骗人 全是',
#  '已破 位别 接刀',
#  '周五 清仓 提现 软件 卸载 告别 股市 止损 发精',
#  '每次 跌 最 猛',
#  '情况 跌 黄金 银行 不',
#  '扑街',
#  '两个 跌停 退市 简单',
#  '[ 大笑 ]',
#  '大户 出货 小散们 跑步 进场 说 一声 傻逼货',
#  '真 尼玛 建 倒数',
#  '双十 股票 打折 还 不快 买 仅限',
#  '底裤 没',
#  '小 双头 下跌',
#  '真 牛 跌 上瘾',
#  '天下 垃圾 唯 独尊',
#  '前 几天 告诉 平安 银行 下跌',
#  '网贷 关门 银行 没 赚钱 项目 资金 上周 都 跑',
#  '亏成 粑',
#  '哎真 垃圾',
#  '块 再 全仓 接回',
#  '烂货 还 真的 跌',
#  '号 开仓到 跌 散户 记忆 七秒 亏',
#  '完 没救 撤',
#  '会 低开',
#  '跌 建仓',
#  '被套 五百 股 扑街',
#  '涨不喜 跌 不 惊 时间 证明',
#  '估计 烂货 下个 礼拜 还要 跌',
#  '被套',
#  '跌成 爹爹',
#  '感觉 真 好 想到 利好 高开低走 卖 平安 银行',
#  '反手 做空',
#  '坑爹 货色 买 跌 垃圾 卖',
#  '换 董事长 还 跌',
#  '跌 三天 歌 还 硬 不',
#  '凉',
#  '空仓 无 压力 踏空 永远 亏损 值得',
#  '放量 大跌 [ 摊手 ]',
#  '看 走势 下午 还要 跌',
#  '难到 向下 跌破 平台',
#  '还要 不要脸',
#  '好不容易 成本 降低 阴跌',
#  '连跌 四天 好 着急',
#  '坑 死 天天 跌 别家 不 脸红',
#  '宁波 银行 干翻',
#  '不 成败论 英雄 中长线 看好 平安 银行 跌',
#  '套 一批 韭菜 助理 两天 出货',
#  '变盘 节点 砸 盘',
#  '太 垃圾',
#  '漫漫 阴跌 路',
#  '进来 被套 去',
#  '憋 三真忍 不了',
#  ...]

# %%
#词袋模型
counter = CountVectorizer(max_df=0.8, min_df=5)
counts = counter.fit_transform(contentlist)
#转为TFidf
tfidfer = TfidfTransformer()
#转为稀疏矩阵
x = tfidfer.fit_transform(counts)
word=counter.get_feature_names()

# %%
#分为训练与测试样本
X_train, X_test, y_train, y_test =train_test_split(x,y)

# %%
clf = MultinomialNB().fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7444444444444445

# %%
#100次交叉验证
nul = 100
scores = cross_val_score(MultinomialNB(), x, y, cv=nul)
plt.plot(range(nul), scores)
plt.show()

# %%
param_range =np.linspace(0.000001,0.1,10)
train_loss, test_loss = validation_curve(MultinomialNB(), X_train,y_train,param_name='alpha', param_range=param_range,n_jobs=8, cv=10)

#平均每一轮的平均方差
train_loss_mean = -np.mean(train_loss, axis=1)
test_loss_mean = -np.mean(test_loss, axis=1)

#可视化图形
plt.plot(param_range, train_loss_mean, 'o-', color="r",
         label="Training")
plt.plot(param_range, test_loss_mean, 'o-', color="b",
        label="Cross-validation")

plt.xlabel("alpha")
plt.ylabel("Loss")
plt.legend(loc="best")
plt.show()

# %%
clf.score(X_train, y_train)
# Out:
# 0.7564959168522642

# %%
pre_pro =clf.predict_proba(x)

# %%
pre_pro
# Out:
# array([[0.39431456, 0.60568544],
#        [0.14040462, 0.85959538],
#        [0.52967633, 0.47032367],
#        ...,
#        [0.81705026, 0.18294974],
#        [0.46393799, 0.53606201],
#        [0.4528582 , 0.5471418 ]])

# %%
df = pd.read_csv('000001-235.csv',encoding='gbk')

# %%
x_c = df.标题.astype(str).values
contentlist = data_to_cu(x_c)

# %%
counts = counter.transform(contentlist)
x_idf = tfidfer.transform(counts)

# %%
pre_ce =clf.predict(x_idf)

# %%
pred_lis  = clf.predict_proba(x_idf)

# %%
#df['pre'] =clf.predict_proba(x_idf)

# %%
neg,pog = [],[]
for i in pred_lis:
    neg.append(i[0])
    pog.append(i[1])

# %%
df['neg'] = neg
df['pog'] = pog

# %%
df.to_excel('数据1.xls')
